# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {'Categories':['Apples', 'Bananas', 'Citrus', 'Kiwi'],
        'Sizes':[15, 30, 45, 10]}

df = pd.DataFrame(data)
df.set_index('Categories', inplace=True)

ax = df.plot.pie(y='Sizes', autopct='%1.1f%%', startangle=90, legend=False)
ax.set_ylabel('')
plt.title('Fruit Distribution in The Market', weight='bold')
plt.show()

# %%
import plotly.express as px

labels = ['Apples', 'Bananas', 'Citrus', 'Kiwi']
values = [25, 30, 45, 10]


fig = px.pie(names=labels, values = values, title = 'Fruit Distribution in The Market')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 8
#       4 values = [25, 30, 45, 10]
#       7 fig = px.pie(names=labels, values = values, title = 'Fruit Distribution in The Market')
# ----> 8 fig.show()
#
# File c:\Users\OliviaAyora\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\OliviaAyora\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
# ...
