# %%
from pytube import Playlist

# %%
playlist_url = input('Enter Playlist: ')
playlist = Playlist(playlist_url)

for video in playlist.videos:
    video.streams.get_highest_resolutions().download()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 4
#       1 playlist_url = input('Enter Playlist: ')
#       2 playlist = Playlist(playlist_url)
# ----> 4 for video in playlist.videos:
#       5     video.streams.get_highest_resolutions().download()
#
# File c:\Python312\Lib\site-packages\pytube\helpers.py:71, in DeferredGeneratorList.__iter__(self)
#      69 while True:
#      70     try:
# ---> 71         curr_item = self[iter_index]
#      72     except IndexError:
#      73         return
#
# File c:\Python312\Lib\site-packages\pytube\helpers.py:57, in DeferredGeneratorList.__getitem__(self, key)
#      55 while len(self._elements) < key_slice.stop:
#      56     try:
# ---> 57         next_item = next(self.gen)
#      58     except StopIteration:
#      59         # If we can't find enough elements for the slice, raise an IndexError
#      60         raise IndexError
#
# File c:\Python312\Lib\site-packages\pytube\contrib\playlist.py:296, in Playlist.videos_generator(self)
#     295 def videos_generator(self):
# --> 296     for url in self.video_urls:
#     297         yield YouTube(url)
#
# File c:\Python312\Lib\site-packages\pytube\helpers.py:71, in DeferredGeneratorList.__iter__(self)
#      69 while True:
#      70     try:
# ---> 71         curr_item = self[iter_index]
#      72     except IndexError:
#      73         return
#
# File c:\Python312\Lib\site-packages\pytube\helpers.py:57, in DeferredGeneratorList.__getitem__(self, key)
#      55 while len(self._elements) < key_slice.stop:
#      56     try:
# ---> 57         next_item = next(self.gen)
#      58     except StopIteration:
#      59         # If we can't find enough elements for the slice, raise an IndexError
#      60         raise IndexError
#
# File c:\Python312\Lib\site-packages\pytube\contrib\playlist.py:281, in Playlist.url_generator(self)
#     276 def url_generator(self):
#     277     """Generator that yields video URLs.
#     278
#     279     :Yields: Video URLs
#     280     """
# --> 281     for page in self._paginate():
#     282         for video in page:
#     283             yield self._video_url(video)
#
# File c:\Python312\Lib\site-packages\pytube\contrib\playlist.py:118, in Playlist._paginate(self, until_watch_id)
#     105 def _paginate(
#     106     self, until_watch_id: Optional[str] = None
#     107 ) -> Iterable[List[str]]:
#     108     """Parse the video links from the page source, yields the /watch?v=
#     109     part from video link
#     110
#    (...)
#     115     :returns: Iterable of lists of YouTube watch ids
#     116     """
#     117     videos_urls, continuation = self._extract_videos(
# --> 118         json.dumps(extract.initial_data(self.html))
#     119     )
#     120     if until_watch_id:
#     121         try:
#
# File c:\Python312\Lib\site-packages\pytube\contrib\playlist.py:58, in Playlist.html(self)
#      56 if self._html:
#      57     return self._html
# ---> 58 self._html = request.get(self.playlist_url)
#      59 return self._html
#
# File c:\Python312\Lib\site-packages\pytube\contrib\playlist.py:48, in Playlist.playlist_url(self)
#      42 @property
#      43 def playlist_url(self):
#      44     """Get the base playlist url.
#      45
#      46     :rtype: str
#      47     """
# ---> 48     return f"https://www.youtube.com/playlist?list={self.playlist_id}"
#
# File c:\Python312\Lib\site-packages\pytube\contrib\playlist.py:39, in Playlist.playlist_id(self)
#      37 if self._playlist_id:
#      38     return self._playlist_id
# ---> 39 self._playlist_id = extract.playlist_id(self._input_url)
#      40 return self._playlist_id
#
# File c:\Python312\Lib\site-packages\pytube\extract.py:151, in playlist_id(url)
#     137 """Extract the ``playlist_id`` from a YouTube url.
#     138
#     139 This function supports the following patterns:
#    (...)
#     148     YouTube playlist id.
#     149 """
#     150 parsed = urllib.parse.urlparse(url)
# --> 151 return parse_qs(parsed.query)['list'][0]
#
# KeyError: 'list'
